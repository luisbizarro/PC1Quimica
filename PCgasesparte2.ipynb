# %% [markdown]
# <a href="https://colab.research.google.com/github/luisbizarro/PC1Quimica/blob/main/PCgasesparte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ejercicio 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install drawdata

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

# %%
#1.1 Ley de Boyle: P vs 1/V
#temperatura constante

draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
mango = pd.read_csv("data.csv")
mango
# Out:
#               x           y  z
# 0     13.104534   46.715231  a
# 1     38.736474   67.704092  a
# 2     39.085495   45.754613  a
# 3     14.789615   24.092401  a
# 4     44.309028   62.605856  a
# ..          ...         ... ..
# 187  675.076912  393.670602  a
# 188  680.134971  431.837232  a
# 189  712.687089  425.592237  a
# 190  678.789283  456.784486  a
# 191  670.513694  429.266404  a
#
# [192 rows x 3 columns]

# %%
#1.2 Ley de charles
#masa y PRESION constante
#V vs T

draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
chaplin = pd.read_csv("data (2).csv")
chaplin
# Out:
#               x           y  z
# 0     52.631760    5.103368  a
# 1     43.325627    2.459114  a
# 2     65.875402   26.492260  a
# 3     54.649885   27.511508  a
# 4     31.639864   -4.448660  a
# ..          ...         ... ..
# 284  653.380874  465.728584  a
# 285  645.146069  439.884638  a
# 286  656.402230  446.450030  a
# 287  682.131136  456.874834  a
# 288  675.274534  416.592696  a
#
# [289 rows x 3 columns]

# %%
# 1.3 Ley de Gay-Lussac
#masa y volumen constante
#P vs T
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
glus = pd.read_csv("data (3).csv")
glus
# Out:
#               x           y  z
# 0     10.055610   96.620553  a
# 1     -8.158858  111.299128  a
# 2     35.375611   76.778507  a
# 3     32.739196   94.442891  a
# 4     11.195588  119.053151  a
# ..          ...         ... ..
# 121  644.468096  515.272611  a
# 122  637.954395  483.936576  a
# 123  622.019243  471.778066  a
# 124  674.521550  483.970392  a
# 125  684.543189  510.350012  a
#
# [126 rows x 3 columns]
